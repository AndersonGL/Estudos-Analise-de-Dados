# %% [markdown]
# <a href="https://colab.research.google.com/github/AndersonGL/Projetos-Analise-de-Dados/blob/main/matpltlib2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plistlib as pli

# %% [markdown]
# #

# %%
import matplotlib.pyplot as plt
plt.hist(data)
plt.show()

# %%
plt.boxplot(data);                                                         #

# %%
x = np.radom.normal(10,0.5,100)
y = np.radom.uniform(0,20,100)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-304abd854575> in <cell line: 0>()
# ----> 1 x = np.radom.normal(10,0.5,100)
#       2 y = np.radom.uniform(0,20,100)
#
# /usr/local/lib/python3.11/dist-packages/numpy/__init__.py in __getattr__(attr)
#     331             raise RuntimeError("Tester was removed in NumPy 1.25.")
#     332
# --> 333         raise AttributeError("module {!r} has no attribute "
#     334                              "{!r}".format(__name__, attr))
#     335
#
# AttributeError: module 'numpy' has no attribute 'radom'

# %%
fig = plt.figure()
ax = plt.axes()
ax.scatter(x,y,marker = 'o', color = 'red', label = 'data1', alpha = 0.5)
ax.scatter(x*0.5, y*0.5, marker ='v' , color = 'black', label = 'data2', alpha = 0.7)
ax.legend();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-3506b12a9e16> in <cell line: 0>()
#       1 fig = plt.figure()
#       2 ax = plt.axes()
# ----> 3 ax.scatter(x,y,marker = 'o', color = 'red', label = 'data1', alpha = 0.5)
#       4 ax.scatter(x*0.5, y*0.5, marker ='v' , color = 'black', label = 'data2', alpha = 0.7)
#       5 ax.legend();
#
# NameError: name 'x' is not defined

# %%
import ploty.express as px
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-39-ece3678cdbfe> in <cell line: 0>()
# ----> 1 import ploty.express as px
#
# ModuleNotFoundError: No module named 'ploty'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
px.data.gapminder()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-9f2c6995e955> in <cell line: 0>()
# ----> 1 px.data.gapminder()
#
# NameError: name 'px' is not defined
