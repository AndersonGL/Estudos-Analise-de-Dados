# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# O Seaborn é uma biblioteca de visualixação de dados dp Python baseado no Matplotlib. Ele provê uma interface de alto nível para construçã de gráficos estatícos atrativos e informativos. Site: Seaborn.org

# %%
# Definir tema

sns.set_theme(style = 'darkgrid')

# %%
# Dados

Base_Dados = sns.load_dataset('tips')

# Verificar

Base_Dados.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Renomendo as colunas

Base_Dados.rename(columns ={
    'total_bill' : 'Total da Conta',
    'tip' : 'Gorjeta',
    'sex' : 'Sexo',
    'smoker' : 'Fumante',
    'day' : 'Dia da Semana',
    'time': 'Período',
    'size' : 'Pessoas na Mesa'    
} , inplace = True)

# %%
Base_Dados.head()
# Out:
#    Total da Conta  Gorjeta    Sexo Fumante Dia da Semana Período  \
# 0           16.99     1.01  Female      No           Sun  Dinner
# 1           10.34     1.66    Male      No           Sun  Dinner
# 2           21.01     3.50    Male      No           Sun  Dinner
# 3           23.68     3.31    Male      No           Sun  Dinner
# 4           24.59     3.61  Female      No           Sun  Dinner
#
#    Pessoas na Mesa
# 0                2
# 1                3
# 2                3
# 3                2
# 4                4

# %%
# Grafico replot

sns.relplot(x='Total da Conta', y='Gorjeta', data=Base_Dados);

# %%
# Grafico replot
# Passando outro parametro como classe no gráfico

sns.relplot(x='Total da Conta', y='Gorjeta', data=Base_Dados, hue = 'Sexo');

# %%
# Gráfico d Linha com 2 Eixos 

sns.relplot(x='Total da Conta', y='Gorjeta', data=Base_Dados, kind = 'line');

# %%
# Gráfico d Linha com 2 Eixos 

sns.relplot(x='Total da Conta', y='Gorjeta', data=Base_Dados, kind = 'line' , hue = 'Fumante');

# %%
sns.histplot(data=Base_Dados, x='Total da Conta')   # Total da Conta
# Out:
# <Axes: xlabel='Total da Conta', ylabel='Count'>

# %%
sns.histplot(data=Base_Dados, x='Total da Conta', hue = 'Fumante')  # Separa os fumante dos não fumantes
# Out:
# <Axes: xlabel='Total da Conta', ylabel='Count'>

# %%
sns.barplot(data=Base_Dados, x='Sexo', y = 'Total da Conta', hue = 'Fumante') # Define entre os sexos quem é fumante e que não.
# Out:
# <Axes: xlabel='Sexo', ylabel='Total da Conta'>

# %%
sns.pairplot(Base_Dados);  # Pega todas as colunas

# %%
sns.pairplot(Base_Dados, hue = 'Sexo');  # Comparação entre colunas base sexo.

# %%
sns.pairplot(Base_Dados, kind = 'kde')

# %%
sns.boxplot(data=Base_Dados, x= 'Dia da Semana', y= 'Total da Conta')

# %%
sns.boxplot(data=Base_Dados, x= 'Dia da Semana', y= 'Total da Conta', hue = 'Sexo')
# Out:
# <Axes: xlabel='Dia da Semana', ylabel='Total da Conta'>
