# %% [markdown]
# <a href="https://colab.research.google.com/github/AndersonGL/Projetos-Analise-de-Dados/blob/main/matpltlib2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install plotly

import numpy as np
import matplotlib.pyplot as plt
import time
import datetime
import unittest
import plotly.express as px
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[24], line 6
#       4 import datetime
#       5 import unittest
# ----> 6 import plotly.express as px
#
# ModuleNotFoundError: No module named 'plotly'

# %% [markdown]
# #

# %%
data = np.random.normal(0, 1, 1000)  # Define the data variable
import matplotlib.pyplot as plt

plt.hist(data)
plt.show()

# %%
plt.boxplot(data);                                                         #

# %%
x = np.random.normal(10, 0.5, 100)
y = np.random.uniform(0, 20, 100)

# %%
fig = plt.figure()
ax = plt.axes()
ax.scatter(x,y,marker = 'o', color = 'red', label = 'data1', alpha = 0.5)
ax.scatter(x*0.5, y*0.5, marker ='v' , color = 'black', label = 'data2', alpha = 0.7)
ax.legend();

# %%
# %pip install plotly

import plotly.express as px
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# Collecting plotly
#   Downloading plotly-6.0.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting narwhals>=1.15.1 (from plotly)
#   Downloading narwhals-1.27.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: packaging in c:\users\anderson g lignelli\appdata\roaming\python\python313\site-packages (from plotly) (24.2)
# Downloading plotly-6.0.0-py3-none-any.whl (14.8 MB)
#    ---------------------------------------- 0.0/14.8 MB ? eta -:--:--
#    ------------------------------- -------- 11.5/14.8 MB 58.9 MB/s eta 0:00:01
#    ---------------------------------------- 14.8/14.8 MB 43.7 MB/s eta 0:00:00
# Downloading narwhals-1.27.1-py3-none-any.whl (308 kB)
# Installing collected packages: narwhals, plotly
# Successfully installed narwhals-1.27.1 plotly-6.0.0

# %%
px.data.gapminder()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 px.data.gapminder()
#
# File c:\Users\Anderson G Lignelli\AppData\Local\Programs\Python\Python313\Lib\site-packages\plotly\data\__init__.py:54, in gapminder(datetimes, centroids, year, pretty_names, return_type)
#      13 def gapminder(
#      14     datetimes=False,
#      15     centroids=False,
#    (...)
#      18     return_type="pandas",
#      19 ):
#      20     """
#      21     Each row represents a country on a given year.
#      22
#    (...)
#      51         If `year` is an integer, the dataset will be filtered for that year
#      52     """
#      53     df = nw.from_native(
# ---> 54         _get_dataset("gapminder", return_type=return_type), eager_only=True
#      55     )
#      56     if year:
#      57         df = df.filter(nw.col("year") == year)
#
# File c:\Users\Anderson G Lignelli\AppData\Local\Programs\Python\Python313\Lib\site-packages\plotly\data\__init__.py:420, in _get_dataset(d, return_type)
#     418     else:
#     419         module_to_load = return_type
# --> 420     backend = import_module(module_to_load)
#     421 except ModuleNotFoundError:
#     422     msg = f"return_type={return_type}, but {return_type} is not installed"
#
# File c:\Users\Anderson G Lignelli\AppData\Local\Programs\Python\Python313\Lib\importlib\__init__.py:88, in import_module(name, package)
#      86             break
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:1026, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File c:\Users\Anderson G Lignelli\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\__init__.py:62
#      59 # let init-time option registration happen
#      60 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 62 from pandas.core.api import (
#      63     # dtype
#      64     ArrowDtype,
#      65     Int8Dtype,
#      66     Int16Dtype,
#      67     Int32Dtype,
#      68     Int64Dtype,
#      69     UInt8Dtype,
#      70     UInt16Dtype,
#      71     UInt32Dtype,
#      72     UInt64Dtype,
#      73     Float32Dtype,
#      74     Float64Dtype,
#      75     CategoricalDtype,
#      76     PeriodDtype,
#      77     IntervalDtype,
#      78     DatetimeTZDtype,
#      79     StringDtype,
#      80     BooleanDtype,
#      81     # missing
#      82     NA,
#      83     isna,
#      84     isnull,
#      85     notna,
#      86     notnull,
#      87     # indexes
#      88     Index,
#      89     CategoricalIndex,
#      90     RangeIndex,
#      91     MultiIndex,
#      92     IntervalIndex,
#      93     TimedeltaIndex,
#      94     DatetimeIndex,
#      95     PeriodIndex,
#      96     IndexSlice,
#      97     # tseries
#      98     NaT,
#      99     Period,
#     100     period_range,
#     101     Timedelta,
#     102     timedelta_range,
#     103     Timestamp,
#     104     date_range,
#     105     bdate_range,
#     106     Interval,
#     107     interval_range,
#     108     DateOffset,
#     109     # conversion
#     110     to_numeric,
#     111     to_datetime,
#     112     to_timedelta,
#     113     # misc
#     114     Flags,
#     115     Grouper,
#     116     factorize,
#     117     unique,
#     118     value_counts,
#     119     NamedAgg,
#     120     array,
#     121     Categorical,
#     122     set_eng_float_format,
#     123     Series,
#     124     DataFrame,
#     125 )
#     127 from pandas.core.dtypes.dtypes import SparseDtype
#     129 from pandas.tseries.api import infer_freq
#
# File c:\Users\Anderson G Lignelli\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\api.py:1
# ----> 1 from pandas._libs import (
#       2     NaT,
#       3     Period,
#       4     Timedelta,
#       5     Timestamp,
#       6 )
#       7 from pandas._libs.missing import NA
#       9 from pandas.core.dtypes.dtypes import (
#      10     ArrowDtype,
#      11     CategoricalDtype,
#    (...)
#      14     PeriodDtype,
#      15 )
#
# File c:\Users\Anderson G Lignelli\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\_libs\__init__.py:18
#      16 import pandas._libs.pandas_parser  # isort: skip # type: ignore[reportUnusedImport]
#      17 import pandas._libs.pandas_datetime  # noqa: F401 # isort: skip # type: ignore[reportUnusedImport]
# ---> 18 from pandas._libs.interval import Interval
#      19 from pandas._libs.tslibs import (
#      20     NaT,
#      21     NaTType,
#    (...)
#      26     iNaT,
#      27 )
#
# File interval.pyx:1, in init pandas._libs.interval()
#
# File hashtable.pyx:1, in init pandas._libs.hashtable()
#
# File missing.pyx:40, in init pandas._libs.missing()
#
# AttributeError: partially initialized module 'pandas' from 'c:\Users\Anderson G Lignelli\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\__init__.py' has no attribute '_pandas_datetime_CAPI' (most likely due to a circular import)

# %%
df = px.data.gapminder().query('country == "Brasil"').set_index('Year')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df = px.data.gapminder().query('country == "Brasil"').set_index('Year')
#
# File c:\Users\Anderson G Lignelli\AppData\Local\Programs\Python\Python313\Lib\site-packages\plotly\data\__init__.py:54, in gapminder(datetimes, centroids, year, pretty_names, return_type)
#      13 def gapminder(
#      14     datetimes=False,
#      15     centroids=False,
#    (...)
#      18     return_type="pandas",
#      19 ):
#      20     """
#      21     Each row represents a country on a given year.
#      22
#    (...)
#      51         If `year` is an integer, the dataset will be filtered for that year
#      52     """
#      53     df = nw.from_native(
# ---> 54         _get_dataset("gapminder", return_type=return_type), eager_only=True
#      55     )
#      56     if year:
#      57         df = df.filter(nw.col("year") == year)
#
# File c:\Users\Anderson G Lignelli\AppData\Local\Programs\Python\Python313\Lib\site-packages\plotly\data\__init__.py:420, in _get_dataset(d, return_type)
#     418     else:
#     419         module_to_load = return_type
# --> 420     backend = import_module(module_to_load)
#     421 except ModuleNotFoundError:
#     422     msg = f"return_type={return_type}, but {return_type} is not installed"
#
# File c:\Users\Anderson G Lignelli\AppData\Local\Programs\Python\Python313\Lib\importlib\__init__.py:88, in import_module(name, package)
#      86             break
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:1026, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File c:\Users\Anderson G Lignelli\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\__init__.py:62
#      59 # let init-time option registration happen
#      60 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 62 from pandas.core.api import (
#      63     # dtype
#      64     ArrowDtype,
#      65     Int8Dtype,
#      66     Int16Dtype,
#      67     Int32Dtype,
#      68     Int64Dtype,
#      69     UInt8Dtype,
#      70     UInt16Dtype,
#      71     UInt32Dtype,
#      72     UInt64Dtype,
#      73     Float32Dtype,
#      74     Float64Dtype,
#      75     CategoricalDtype,
#      76     PeriodDtype,
#      77     IntervalDtype,
#      78     DatetimeTZDtype,
#      79     StringDtype,
#      80     BooleanDtype,
#      81     # missing
#      82     NA,
#      83     isna,
#      84     isnull,
#      85     notna,
#      86     notnull,
#      87     # indexes
#      88     Index,
#      89     CategoricalIndex,
#      90     RangeIndex,
#      91     MultiIndex,
#      92     IntervalIndex,
#      93     TimedeltaIndex,
#      94     DatetimeIndex,
#      95     PeriodIndex,
#      96     IndexSlice,
#      97     # tseries
#      98     NaT,
#      99     Period,
#     100     period_range,
#     101     Timedelta,
#     102     timedelta_range,
#     103     Timestamp,
#     104     date_range,
#     105     bdate_range,
#     106     Interval,
#     107     interval_range,
#     108     DateOffset,
#     109     # conversion
#     110     to_numeric,
#     111     to_datetime,
#     112     to_timedelta,
#     113     # misc
#     114     Flags,
#     115     Grouper,
#     116     factorize,
#     117     unique,
#     118     value_counts,
#     119     NamedAgg,
#     120     array,
#     121     Categorical,
#     122     set_eng_float_format,
#     123     Series,
#     124     DataFrame,
#     125 )
#     127 from pandas.core.dtypes.dtypes import SparseDtype
#     129 from pandas.tseries.api import infer_freq
#
# File c:\Users\Anderson G Lignelli\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\api.py:1
# ----> 1 from pandas._libs import (
#       2     NaT,
#       3     Period,
#       4     Timedelta,
#       5     Timestamp,
#       6 )
#       7 from pandas._libs.missing import NA
#       9 from pandas.core.dtypes.dtypes import (
#      10     ArrowDtype,
#      11     CategoricalDtype,
#    (...)
#      14     PeriodDtype,
#      15 )
#
# File c:\Users\Anderson G Lignelli\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\_libs\__init__.py:18
#      16 import pandas._libs.pandas_parser  # isort: skip # type: ignore[reportUnusedImport]
#      17 import pandas._libs.pandas_datetime  # noqa: F401 # isort: skip # type: ignore[reportUnusedImport]
# ---> 18 from pandas._libs.interval import Interval
#      19 from pandas._libs.tslibs import (
#      20     NaT,
#      21     NaTType,
#    (...)
#      26     iNaT,
#      27 )
#
# File interval.pyx:1, in init pandas._libs.interval()
#
# File hashtable.pyx:1, in init pandas._libs.hashtable()
#
# File missing.pyx:40, in init pandas._libs.missing()
#
# AttributeError: partially initialized module 'pandas' from 'c:\Users\Anderson G Lignelli\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\__init__.py' has no attribute '_pandas_datetime_CAPI' (most likely due to a circular import)

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined
